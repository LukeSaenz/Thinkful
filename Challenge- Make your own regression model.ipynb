# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

# Suppress annoying harmless error.
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
df = pd.read_excel('table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls')

#Dropping the first few rows
df = df.drop([0, 1, 2, 3, 4])

#Drop the blank column
df = df.drop(columns='Unnamed: 4')

df.head()
# Out:
#                     Table 8 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 5  \
# 5  Addison Town and Village       2577          3          0          0
# 6             Akron Village       2846          3          0          0
# 7                    Albany      97956        791          8         30
# 8            Albion Village       6388         23          0          3
# 9            Alfred Village       4089          5          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 5          0          3         24          3          20           1
# 6          0          3         16          1          15           0
# 7        227        526       4090        705        3243         142
# 8          4         16        223         53         165           5
# 9          3          2         46         10          36           0
#
#   Unnamed: 12
# 5           0
# 6           0
# 7         NaN
# 8         NaN
# 9         NaN

# %%
df.columns = ['city', 'population', 'violent_crime', 'murder_manslaughter', 'rape',
             'robbery', 'agg_assault', 'property_crime', 'burglary', 'larceny', 'motor_theft', 'arson']

df.head(30)
# Out:
#                         city population violent_crime murder_manslaughter  \
# 5   Addison Town and Village       2577             3                   0
# 6              Akron Village       2846             3                   0
# 7                     Albany      97956           791                   8
# 8             Albion Village       6388            23                   0
# 9             Alfred Village       4089             5                   0
# 10          Allegany Village       1781             3                   0
# 11              Amherst Town     118296           107                   1
# 12        Amityville Village       9519             9                   0
# 13                 Amsterdam      18182            30                   0
# 14            Arcade Village       2053             0                   0
# 15           Ardsley Village       4523             5                   0
# 16         Asharoken Village        658             0                   0
# 17            Attica Village       2522             2                   0
# 18                    Auburn      27270            96                   1
# 19              Avon Village       3333             1                   0
# 20     Baldwinsville Village       7473             5                   0
# 21      Ballston Spa Village       5418             8                   0
# 22                   Batavia      15374            57                   0
# 23              Bath Village       5733            15                   0
# 24              Bedford Town      17627             5                   0
# 25            Bethlehem Town      34243            13                   0
# 26                Binghamton      46304           284                   3
# 27               Black River       1410             0                   0
# 28       Blooming Grove Town      12001             8                   0
# 29           Bolivar Village       1022             1                   0
# 30               Bolton Town       2325             2                   0
# 31         Boonville Village       2054             1                   0
# 32                Brant Town       2065             4                   0
# 33                  Brewster       2358             0                   0
# 34  Briarcliff Manor Village       7976             1                   0
#
#    rape robbery agg_assault property_crime burglary larceny motor_theft arson
# 5     0       0           3             24        3      20           1     0
# 6     0       0           3             16        1      15           0     0
# 7    30     227         526           4090      705    3243         142   NaN
# 8     3       4          16            223       53     165           5   NaN
# 9     0       3           2             46       10      36           0   NaN
# 10    0       0           3             10        0      10           0     0
# 11    7      31          68           2118      204    1882          32     3
# 12    2       4           3            210       16     188           6     1
# 13    0      12          18            405       99     291          15     0
# 14    0       0           0             39        3      35           1     0
# 15    0       3           2             33        4      28           1     0
# 16    0       0           0              2        0       2           0     0
# 17    0       0           2              5        0       4           1     0
# 18   20      22          53            859      132     721           6   NaN
# 19    0       1           0             25        3      20           2   NaN
# 20    0       1           4             88       10      77           1     0
# 21    0       3           5             94       16      78           0     1
# 22    7      13          37            559      103     454           2   NaN
# 23    1       3          11            191       32     157           2     2
# 24    0       1           4            156       26     127           3   NaN
# 25    0       3          10            442       50     388           4   NaN
# 26   19     101         161           2349      525    1767          57   NaN
# 27    0       0           0             14        2      12           0     0
# 28    1       0           7             99       20      72           7   NaN
# 29    0       0           1              4        2       2           0     0
# 30    0       0           2             24        4      20           0     0
# 31    0       0           1             20        6      14           0     0
# 32    0       1           3             31        9      20           2     0
# 33    0       0           0             13        3      10           0     0
# 34    0       0           1             11        1      10           0     0

# %%
#Replacing NaN values with 0
#df.arson[df.arson.isnull()] = 0

#Replacing NaN values with rounded mean
df.arson[df.arson.isnull()] = round(df.arson.mean(),0)

df.arson.mean()
# Out:
# 1.937142857142857

# %%
df.head(30)
# Out:
#                         city population violent_crime murder_manslaughter  \
# 5   Addison Town and Village       2577             3                   0
# 6              Akron Village       2846             3                   0
# 7                     Albany      97956           791                   8
# 8             Albion Village       6388            23                   0
# 9             Alfred Village       4089             5                   0
# 10          Allegany Village       1781             3                   0
# 11              Amherst Town     118296           107                   1
# 12        Amityville Village       9519             9                   0
# 13                 Amsterdam      18182            30                   0
# 14            Arcade Village       2053             0                   0
# 15           Ardsley Village       4523             5                   0
# 16         Asharoken Village        658             0                   0
# 17            Attica Village       2522             2                   0
# 18                    Auburn      27270            96                   1
# 19              Avon Village       3333             1                   0
# 20     Baldwinsville Village       7473             5                   0
# 21      Ballston Spa Village       5418             8                   0
# 22                   Batavia      15374            57                   0
# 23              Bath Village       5733            15                   0
# 24              Bedford Town      17627             5                   0
# 25            Bethlehem Town      34243            13                   0
# 26                Binghamton      46304           284                   3
# 27               Black River       1410             0                   0
# 28       Blooming Grove Town      12001             8                   0
# 29           Bolivar Village       1022             1                   0
# 30               Bolton Town       2325             2                   0
# 31         Boonville Village       2054             1                   0
# 32                Brant Town       2065             4                   0
# 33                  Brewster       2358             0                   0
# 34  Briarcliff Manor Village       7976             1                   0
#
#    rape robbery agg_assault property_crime burglary larceny motor_theft arson
# 5     0       0           3             24        3      20           1     0
# 6     0       0           3             16        1      15           0     0
# 7    30     227         526           4090      705    3243         142 2.000
# 8     3       4          16            223       53     165           5 2.000
# 9     0       3           2             46       10      36           0 2.000
# 10    0       0           3             10        0      10           0     0
# 11    7      31          68           2118      204    1882          32     3
# 12    2       4           3            210       16     188           6     1
# 13    0      12          18            405       99     291          15     0
# 14    0       0           0             39        3      35           1     0
# 15    0       3           2             33        4      28           1     0
# 16    0       0           0              2        0       2           0     0
# 17    0       0           2              5        0       4           1     0
# 18   20      22          53            859      132     721           6 2.000
# 19    0       1           0             25        3      20           2 2.000
# 20    0       1           4             88       10      77           1     0
# 21    0       3           5             94       16      78           0     1
# 22    7      13          37            559      103     454           2 2.000
# 23    1       3          11            191       32     157           2     2
# 24    0       1           4            156       26     127           3 2.000
# 25    0       3          10            442       50     388           4 2.000
# 26   19     101         161           2349      525    1767          57 2.000
# 27    0       0           0             14        2      12           0     0
# 28    1       0           7             99       20      72           7 2.000
# 29    0       0           1              4        2       2           0     0
# 30    0       0           2             24        4      20           0     0
# 31    0       0           1             20        6      14           0     0
# 32    0       1           3             31        9      20           2     0
# 33    0       0           0             13        3      10           0     0
# 34    0       0           1             11        1      10           0     0

# %%
#I see a handful of NaNs (particularly in arson), let's remove that one too
#df = df.drop(columns='arson')

# %%
df['population_squared'] = df['population'] **2

df.head()
# Out:
#                        city population violent_crime murder_manslaughter rape  \
# 5  Addison Town and Village       2577             3                   0    0
# 6             Akron Village       2846             3                   0    0
# 7                    Albany      97956           791                   8   30
# 8            Albion Village       6388            23                   0    3
# 9            Alfred Village       4089             5                   0    0
#
#   robbery agg_assault property_crime burglary larceny motor_theft arson  \
# 5       0           3             24        3      20           1     0
# 6       0           3             16        1      15           0     0
# 7     227         526           4090      705    3243         142 2.000
# 8       4          16            223       53     165           5 2.000
# 9       3           2             46       10      36           0 2.000
#
#   population_squared
# 5            6640929
# 6            8099716
# 7         9595377936
# 8           40806544
# 9           16719921

# %% [markdown]
# ### Propertycrime=α+Population+Population2+Murder+Robbery

# %%
#Attempting to drop all NaN values rows in anticipation of the following error...
#df.dropna()

# %%
df.columns
# Out:
# Index(['city', 'population', 'violent_crime', 'murder_manslaughter', 'rape',
#        'robbery', 'agg_assault', 'property_crime', 'burglary', 'larceny',
#        'motor_theft', 'arson', 'population_squared'],
#       dtype='object')

# %%
X.describe

#More rows to drop
df = df.drop([352, 353, 354])

#X.isnull().sum()

# %%
# Instantiate and fit our model.
regr = linear_model.LinearRegression()
Y = df['property_crime'].values.reshape(-1, 1)
X = df[['population', 'population_squared', 'murder_manslaughter', 'robbery']]
regr.fit(X, Y)
plt.show()

# Inspect the results.
print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(X, Y))


#What's happening here?
# Out:
# Coefficients:
#  [[ 1.59183918e-02 -1.01014349e-09  1.17553360e+02  2.09300109e+00]]
#
# Intercept:
#  [24.32759066]
#
# R-squared:
# 0.998741790547199

# %%
px = X.head(1)
px
# Out:
#   population population_squared murder_manslaughter robbery
# 5       2577            6640929                   0       0

# %%
regr.predict(px)
# Out:
# array([[65.34257809]])

# %%
df.head(1)
# Out:
#                        city population violent_crime murder_manslaughter rape  \
# 5  Addison Town and Village       2577             3                   0    0
#
#   robbery agg_assault property_crime burglary larceny motor_theft arson  \
# 5       0           3             24        3      20           1     0
#
#   population_squared
# 5            6640929
