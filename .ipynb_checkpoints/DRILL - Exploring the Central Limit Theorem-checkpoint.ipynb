# %% [markdown]
# Now that you have some code to create your own populations, sample them, and compare the samples to the populations, it's time to experiment. Using your own Jupyter notebook, or a copy of the notebook from the previous assignment, reproduce the pop1 and pop2 populations and samples, using numpy's binomial function.
#
# Specifically, create two binomially distributed populations with n equal to 10 and size equal to 10000. The p-value of pop1 should be 0.2 and the p-value of pop2 should be 0.5. Using a sample size of 100, calculate the means and standard deviations of your samples.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Create the binomially distributed populations
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000)

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
#Create two samples, size 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
#Calculate the means and standard deviations of the samples
print('Sample 1 mean: ' + str(sample1.mean()))
print('Sample 2 mean: ' +str(sample2.mean()))
print('Sample 1 standard deviation: ' + str(sample1.std()))
print('Sample 2 standard deviation: ' + str(sample2.std()))
# Out:
# Sample 1 mean: 2.0
# Sample 2 mean: 5.29
# Sample 1 standard deviation: 1.3266499161421599
# Sample 2 standard deviation: 1.6142800252744254

# %% [markdown]
# 1) Increase the size of your samples from 100 to 1000, then calculate the means and standard deviations for your new samples and create histograms for each. Repeat this again, decreasing the size of your samples to 20. What values change, and what remain the same?

# %%
#I expect that the standard deviation will decrease when the sample size increases, and increase when the
#sample size increases.

# %%
#Create two samples, size 1000
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

#Calculate the means and standard deviations of the samples
print('Sample 1 mean: ' + str(sample1.mean()))
print('Sample 2 mean: ' +str(sample2.mean()))
print('Sample 1 standard deviation: ' + str(sample1.std()))
print('Sample 2 standard deviation: ' + str(sample2.std()))
# Out:
# Sample 1 mean: 2.906
# Sample 2 mean: 5.033
# Sample 1 standard deviation: 1.4950464875715404
# Sample 2 standard deviation: 1.669104849912072

# %%
#Create two samples, size 20
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

#Calculate the means and standard deviations of the samples
print('Sample 1 mean: ' + str(sample1.mean()))
print('Sample 2 mean: ' +str(sample2.mean()))
print('Sample 1 standard deviation: ' + str(sample1.std()))
print('Sample 2 standard deviation: ' + str(sample2.std()))
# Out:
# Sample 1 mean: 3.05
# Sample 2 mean: 5.6
# Sample 1 standard deviation: 1.883480820183736
# Sample 2 standard deviation: 1.9849433241279208

# %% [markdown]
# 2) Change the probability value (p in the NumPy documentation) for pop1 to 0.3, then take new samples and compute the t-statistic and p-value.

# %%
#Change the  value for pop1 to 0.3
pop1 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 10000)

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

#Create two samples, size 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=12.584894858764564, pvalue=4.539184759967822e-27)

# %% [markdown]
# Then change the probability value p for group 1 to 0.4, and do it again.

# %%
#Change the  value for pop1 to 0.4
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 10000)

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

#Create two samples, size 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=4.907809892217132, pvalue=1.932019490011966e-06)

# %% [markdown]
# 3) Change the distribution of your populations from binomial to a distribution of your choice. Do the sample mean values still accurately represent the population values?

# %%
#Change the  distribution to gamma
pop1 = np.random.gamma(10, 0.2, 10000)
pop2 = np.random.gamma(10,0.5, 10000)

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

#Create two samples, size 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=19.714639616832237, pvalue=1.7273764445866223e-40)
